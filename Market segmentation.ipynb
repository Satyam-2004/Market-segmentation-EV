# %% [markdown]
# # Two - wheeler review dataset analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import nltk 
from nltk.sentiment import SentimentIntensityAnalyzer 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import warnings

# %%
data_bw = pd.read_csv("ev2_bikewale.csv")
data_bw.head()
# Out:
#                                               review    Used it for  \
# 0  We all checked the bike's capacity to be 150 k...  Daily Commute
# 1  Performance is very poor on this bike. The cha...     Everything
# 2  I purchased this in April 2022 and the sales s...  Daily Commute
# 3  If any issues come in scooty parts not availab...  Daily Commute
# 4  Don't buy this vehicle unless you have a near ...  Daily Commute
#
#        Owned for      Ridden for  rating  Visual Appeal  Reliability  \
# 0    Never owned             NaN       1            3.0          4.0
# 1         > 1 yr      < 5000 kms       1            3.0          1.0
# 2     < 3 months      < 5000 kms       3            4.0          4.0
# 3  6 months-1 yr  5000-10000 kms       1            1.0          1.0
# 4  6 months-1 yr      < 5000 kms       1            3.0          4.0
#
#    Performance  Service Experience  Extra Features  Comfort  Maintenance cost  \
# 0          NaN                 NaN             NaN      4.0               NaN
# 1          NaN                 1.0             NaN      3.0               NaN
# 2          NaN                 2.0             NaN      5.0               NaN
# 3          NaN                 1.0             NaN      1.0               NaN
# 4          NaN                 1.0             NaN      3.0               NaN
#
#    Value for Money Model Name
# 0              1.0  TVS iQube
# 1              3.0  TVS iQube
# 2              2.0  TVS iQube
# 3              1.0  TVS iQube
# 4              2.0  TVS iQube

# %%
((data_bw.isnull().sum() * 100/data_bw.shape[0])).sort_values(ascending = False)
# Out:
# Maintenance cost      78.672986
# Extra Features        78.080569
# Performance           59.123223
# Value for Money       53.791469
# Comfort               37.203791
# Ridden for            20.853081
# Service Experience    16.706161
# Reliability           15.165877
# Visual Appeal         12.440758
# review                 5.568720
# Used it for            0.000000
# Owned for              0.000000
# rating                 0.000000
# Model Name             0.000000
# dtype: float64

# %%
data_bw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review              797 non-null    object
#  1   Used it for         844 non-null    object
#  2   Owned for           844 non-null    object
#  3   Ridden for          668 non-null    object
#  4   rating              844 non-null    int64
#  5   Visual Appeal       739 non-null    float64
#  6   Reliability         716 non-null    float64
#  7   Performance         345 non-null    float64
#  8   Service Experience  703 non-null    float64
#  9   Extra Features      185 non-null    float64
#  10  Comfort             530 non-null    float64
#  11  Maintenance cost    180 non-null    float64
#  12  Value for Money     390 non-null    float64
#  13  Model Name          844 non-null    object
# dtypes: float64(8), int64(1), object(5)
# memory usage: 92.4+ KB

# %%
sentiments = SentimentIntensityAnalyzer()
sentiments_list = []

for review_text in data_bw['review']:
    if pd.isna(review_text):
        sentiments_list.append('neutral')
        continue
    sentiment_scores = sentiments.polarity_scores(review_text)

    positive_score = sentiment_scores['pos']
    negative_score = sentiment_scores['neg']

    if positive_score > negative_score:
        sentiment_label = 'positive'
    elif positive_score < negative_score:
        sentiment_label = 'negative'
    else:
        sentiment_label = 'neutral'

    sentiments_list.append(sentiment_label)
    
data_bw['sentiment'] = sentiments_list

# %%
data_bw['sentiment'].value_counts()
# Out:
# sentiment
# positive    527
# negative    264
# neutral      53
# Name: count, dtype: int64

# %%
data_segment = data_bw[['Used it for', 'Owned for', 'Ridden for', 'rating', 'Visual Appeal', 'Reliability', 'Performance',
        'Service Experience', 'Extra Features', 'Comfort', 'Maintenance cost', 'Value for Money', 'sentiment']].copy()

# %%
data_segment.head()
# Out:
#      Used it for      Owned for      Ridden for  rating  Visual Appeal  \
# 0  Daily Commute    Never owned             NaN       1            3.0
# 1     Everything         > 1 yr      < 5000 kms       1            3.0
# 2  Daily Commute     < 3 months      < 5000 kms       3            4.0
# 3  Daily Commute  6 months-1 yr  5000-10000 kms       1            1.0
# 4  Daily Commute  6 months-1 yr      < 5000 kms       1            3.0
#
#    Reliability  Performance  Service Experience  Extra Features  Comfort  \
# 0          4.0          NaN                 NaN             NaN      4.0
# 1          1.0          NaN                 1.0             NaN      3.0
# 2          4.0          NaN                 2.0             NaN      5.0
# 3          1.0          NaN                 1.0             NaN      1.0
# 4          4.0          NaN                 1.0             NaN      3.0
#
#    Maintenance cost  Value for Money sentiment
# 0               NaN              1.0  negative
# 1               NaN              3.0  negative
# 2               NaN              2.0  positive
# 3               NaN              1.0  negative
# 4               NaN              2.0  negative

# %%
data_bw.head()
# Out:
#                                               review    Used it for  \
# 0  We all checked the bike's capacity to be 150 k...  Daily Commute
# 1  Performance is very poor on this bike. The cha...     Everything
# 2  I purchased this in April 2022 and the sales s...  Daily Commute
# 3  If any issues come in scooty parts not availab...  Daily Commute
# 4  Don't buy this vehicle unless you have a near ...  Daily Commute
#
#        Owned for      Ridden for  rating  Visual Appeal  Reliability  \
# 0    Never owned             NaN       1            3.0          4.0
# 1         > 1 yr      < 5000 kms       1            3.0          1.0
# 2     < 3 months      < 5000 kms       3            4.0          4.0
# 3  6 months-1 yr  5000-10000 kms       1            1.0          1.0
# 4  6 months-1 yr      < 5000 kms       1            3.0          4.0
#
#    Performance  Service Experience  Extra Features  Comfort  Maintenance cost  \
# 0          NaN                 NaN             NaN      4.0               NaN
# 1          NaN                 1.0             NaN      3.0               NaN
# 2          NaN                 2.0             NaN      5.0               NaN
# 3          NaN                 1.0             NaN      1.0               NaN
# 4          NaN                 1.0             NaN      3.0               NaN
#
#    Value for Money Model Name sentiment
# 0              1.0  TVS iQube  negative
# 1              3.0  TVS iQube  negative
# 2              2.0  TVS iQube  positive
# 3              1.0  TVS iQube  negative
# 4              2.0  TVS iQube  negative

# %%
msno.matrix(data_bw)
# Out:
# <Axes: >

# %%
data_segment =data_bw.iloc[:, 5:13].copy()

# %%
data_segment = data_segment.fillna(0.)

# %%
data_segment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Visual Appeal       844 non-null    float64
#  1   Reliability         844 non-null    float64
#  2   Performance         844 non-null    float64
#  3   Service Experience  844 non-null    float64
#  4   Extra Features      844 non-null    float64
#  5   Comfort             844 non-null    float64
#  6   Maintenance cost    844 non-null    float64
#  7   Value for Money     844 non-null    float64
# dtypes: float64(8)
# memory usage: 52.9 KB

# %%
data_segment.mean()
# Out:
# Visual Appeal         3.309242
# Reliability           2.811611
# Performance           1.441943
# Service Experience    2.619668
# Extra Features        0.643365
# Comfort               2.300948
# Maintenance cost      0.723934
# Value for Money       1.562796
# dtype: float64

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_segment)

# %%
pca = PCA(random_state = 42)
pca.fit(data_scaled)
# Out:
# PCA(random_state=42)

# %%
data_pca = pca.transform(data_scaled)

# %%
df_pca = pd.DataFrame(data_pca, columns = [f'PC{x + 1}' for x in range(len(data_segment.columns))])

# %%
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.291227 -1.038055  0.354864 -0.623469 -1.102720 -0.169287 -0.438012
# 1  0.710801 -1.394405 -0.360466 -0.621671  0.320899 -0.086053 -0.426279
# 2 -0.849149 -1.189765  0.167683 -0.410898 -0.409054 -0.191904 -0.329993
# 3  1.967022 -0.878935 -0.100197  0.330003 -0.075822  0.069599  0.013068
# 4  0.078940 -1.017161 -0.079210 -0.324132 -0.961554  0.005517 -0.107260
#
#         PC8
# 0  0.957827
# 1 -0.149917
# 2  0.830738
# 3  0.011328
# 4  0.427972

# %%
pca_summary = pd.DataFrame({'Standard Deviation':df_pca.std(),
                            'Proportion of Variance': pca.explained_variance_ratio_,
                            'Cumultive Proportion': pca.explained_variance_ratio_.cumsum()})

# %%
pca_summary
# Out:
#      Standard Deviation  Proportion of Variance  Cumultive Proportion
# PC1            1.845017                0.425007              0.425007
# PC2            1.736646                0.376546              0.801553
# PC3            0.903486                0.101915              0.903468
# PC4            0.517750                0.033468              0.936936
# PC5            0.405239                0.020503              0.957439
# PC6            0.379558                0.017987              0.975426
# PC7            0.337883                0.014254              0.989680
# PC8            0.287510                0.010320              1.000000

# %%
factor_loadings = pd.DataFrame(pca.components_, columns = data_segment.columns, index = df_pca.columns).T

# %%
kmeans = data_km28[2]

# %%
data_clust = pd.DataFrame(data_scaled, columns = data_segment.columns)
data_clust['cluster'] = kmeans.labels_

# %%
data_pca = df_pca.copy()
data_pca['cluster'] = kmeans.labels_

# %%
data_profile = data_segment.copy()
data_profile['cluster'] = kmeans.labels_
columns_segment = data_clust.columns
data_pivot = data_profile[columns_segment].groupby('cluster').mean().T
data_pivot_mean = data_pivot.mean(axis = 1).reset_index()
data_pivot_mean.columns = ['Variable', 'Value']
plt.figure(figsize = (12, 9))
for i in range(4):
    plt.subplot(2, 2, i+1)
    sns.barplot(data_pivot, x = i, y = data_pivot.index)
    sns.scatterplot(data_pivot_mean, x = 'Value', y = 'Variable', color = 'red')
    for index, row in data_pivot_mean.iterrows():
        plt.hlines(y=row['Variable'], xmin=0, xmax=row['Value'], colors='red', alpha = 0.2)
    plt.ylabel("")
    plt.xlabel("")
    plt.title(f"Cluster {i}: {data_profile['cluster'].value_counts()[i]} ({data_profile['cluster'].value_counts()[i]*100/len(data_profile):.0f}%)")
plt.suptitle("Segment profile plot for the four-segment solution for the EV 2-Wheeler data set", fontsize = 15)
plt.tight_layout()
plt.savefig("segment_profile.png")
plt.show()

# %%
factor_loadings.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_cf7db_row0_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_cf7db_row0_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_cf7db_row0_col2, #T_cf7db_row1_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_cf7db_row0_col3, #T_cf7db_row1_col0, #T_cf7db_row1_col4, #T_cf7db_row5_col6, #T_cf7db_row6_col5, #T_cf7db_row7_col1, #T_cf7db_row7_col2, #T_cf7db_row7_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cf7db_row0_col4 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_cf7db_row0_col5, #T_cf7db_row6_col7 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_cf7db_row0_col6, #T_cf7db_row2_col2, #T_cf7db_row3_col3, #T_cf7db_row3_col4, #T_cf7db_row4_col1, #T_cf7db_row4_col5, #T_cf7db_row5_col7, #T_cf7db_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cf7db_row0_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_cf7db_row1_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_cf7db_row1_col3 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_cf7db_row1_col5 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_cf7db_row1_col6 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_cf7db_row1_col7, #T_cf7db_row5_col4 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col1 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col4, #T_cf7db_row6_col6 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_cf7db_row2_col6 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_cf7db_row2_col7, #T_cf7db_row3_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_cf7db_row3_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_cf7db_row3_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_cf7db_row3_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_cf7db_row3_col6 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_cf7db_row3_col7 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_cf7db_row4_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_cf7db_row4_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_cf7db_row4_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_cf7db_row4_col4 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_cf7db_row4_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_cf7db_row4_col7 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_cf7db_row5_col0, #T_cf7db_row6_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_cf7db_row5_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_cf7db_row5_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_cf7db_row5_col3 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_cf7db_row5_col5 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_cf7db_row6_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_cf7db_row6_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_cf7db_row6_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_cf7db_row7_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_cf7db_row7_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_cf7db_row7_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_cf7db_row7_col5 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_cf7db_row7_col6 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# </style>
# <table id="T_cf7db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf7db_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_cf7db_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_cf7db_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_cf7db_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_cf7db_level0_col4" class="col_heading level0 col4" >PC5</th>
#       <th id="T_cf7db_level0_col5" class="col_heading level0 col5" >PC6</th>
#       <th id="T_cf7db_level0_col6" class="col_heading level0 col6" >PC7</th>
#       <th id="T_cf7db_level0_col7" class="col_heading level0 col7" >PC8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf7db_level0_row0" class="row_heading level0 row0" >Visual Appeal</th>
#       <td id="T_cf7db_row0_col0" class="data row0 col0" >-0.480170</td>
#       <td id="T_cf7db_row0_col1" class="data row0 col1" >0.117814</td>
#       <td id="T_cf7db_row0_col2" class="data row0 col2" >0.063320</td>
#       <td id="T_cf7db_row0_col3" class="data row0 col3" >-0.730598</td>
#       <td id="T_cf7db_row0_col4" class="data row0 col4" >0.247014</td>
#       <td id="T_cf7db_row0_col5" class="data row0 col5" >0.105903</td>
#       <td id="T_cf7db_row0_col6" class="data row0 col6" >0.375474</td>
#       <td id="T_cf7db_row0_col7" class="data row0 col7" >0.067539</td>
#     </tr>
#     <tr>
#       <th id="T_cf7db_level0_row1" class="row_heading level0 row1" >Reliability</th>
#       <td id="T_cf7db_row1_col0" class="data row1 col0" >-0.494758</td>
#       <td id="T_cf7db_row1_col1" class="data row1 col1" >0.124910</td>
#       <td id="T_cf7db_row1_col2" class="data row1 col2" >-0.002776</td>
#       <td id="T_cf7db_row1_col3" class="data row1 col3" >0.152447</td>
#       <td id="T_cf7db_row1_col4" class="data row1 col4" >-0.819319</td>
#       <td id="T_cf7db_row1_col5" class="data row1 col5" >0.060484</td>
#       <td id="T_cf7db_row1_col6" class="data row1 col6" >0.117211</td>
#       <td id="T_cf7db_row1_col7" class="data row1 col7" >0.166384</td>
#     </tr>
#     <tr>
#       <th id="T_cf7db_level0_row2" class="row_heading level0 row2" >Performance</th>
#       <td id="T_cf7db_row2_col0" class="data row2 col0" >-0.128721</td>
#       <td id="T_cf7db_row2_col1" class="data row2 col1" >0.459145</td>
#       <td id="T_cf7db_row2_col2" class="data row2 col2" >0.574833</td>
#       <td id="T_cf7db_row2_col3" class="data row2 col3" >-0.005549</td>
#       <td id="T_cf7db_row2_col4" class="data row2 col4" >-0.019902</td>
#       <td id="T_cf7db_row2_col5" class="data row2 col5" >-0.025704</td>
#       <td id="T_cf7db_row2_col6" class="data row2 col6" >-0.288468</td>
#       <td id="T_cf7db_row2_col7" class="data row2 col7" >-0.598232</td>
#     </tr>
#     <tr>
#       <th id="T_cf7db_level0_row3" class="row_heading level0 row3" >Service Experience</th>
#       <td id="T_cf7db_row3_col0" class="data row3 col0" >-0.486499</td>
#       <td id="T_cf7db_row3_col1" class="data row3 col1" >0.100691</td>
#       <td id="T_cf7db_row3_col2" class="data row3 col2" >-0.054176</td>
#       <td id="T_cf7db_row3_col3" class="data row3 col3" >0.653781</td>
#       <td id="T_cf7db_row3_col4" class="data row3 col4" >0.470391</td>
#       <td id="T_cf7db_row3_col5" class="data row3 col5" >0.052432</td>
#       <td id="T_cf7db_row3_col6" class="data row3 col6" >0.311210</td>
#       <td id="T_cf7db_row3_col7" class="data row3 col7" >-0.044129</td>
#     </tr>
#     <tr>
#       <th id="T_cf7db_level0_row4" class="row_heading level0 row4" >Extra Features</th>
#       <td id="T_cf7db_row4_col0" class="data row4 col0" >-0.024373</td>
#       <td id="T_cf7db_row4_col1" class="data row4 col1" >0.519633</td>
#       <td id="T_cf7db_row4_col2" class="data row4 col2" >-0.364578</td>
#       <td id="T_cf7db_row4_col3" class="data row4 col3" >-0.023208</td>
#       <td id="T_cf7db_row4_col4" class="data row4 col4" >0.116821</td>
#       <td id="T_cf7db_row4_col5" class="data row4 col5" >0.559390</td>
#       <td id="T_cf7db_row4_col6" class="data row4 col6" >-0.456829</td>
#       <td id="T_cf7db_row4_col7" class="data row4 col7" >0.246323</td>
#     </tr>
#     <tr>
#       <th id="T_cf7db_level0_row5" class="row_heading level0 row5" >Comfort</th>
#       <td id="T_cf7db_row5_col0" class="data row5 col0" >-0.418255</td>
#       <td id="T_cf7db_row5_col1" class="data row5 col1" >-0.304266</td>
#       <td id="T_cf7db_row5_col2" class="data row5 col2" >0.249807</td>
#       <td id="T_cf7db_row5_col3" class="data row5 col3" >-0.0

# %%
index_names = factor_loadings.index

sns.scatterplot(df_pca, x ='PC1', y ='PC2', color = 'grey')

for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text((factor_loadings['PC1'][i] * 3.5), factor_loadings['PC2'][i] * 3.5, index_names[i], fontsize=12, ha='center', color='red', va = 'center_baseline')

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('A Principal components analysis of the EV 2-Wheeler data set')
plt.grid(True)
plt.savefig("pca_2w.png", format = 'png')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\2768264604.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\2768264604.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text((factor_loadings['PC1'][i] * 3.5), factor_loadings['PC2'][i] * 3.5, index_names[i], fontsize=12, ha='center', color='red', va = 'center_baseline')

# %%
data_km28 = [KMeans(n_clusters = k, random_state = 42).fit(data_scaled) for k in range(2, 9)]

# %%
wcss = [model.inertia_ for model in data_km28]

# %%
fig = plt.figure(figsize = (6,4))
sns.barplot(x = list(range(2, 9)), y = wcss, color ='grey')
plt.xlabel("Segments")
plt.ylabel('Sum fo Within Cluster Distances')
plt.title("Scree plot for the EV 2-Wheeler data set")
plt.savefig("scree_plot.png")
plt.show()

# %%
wcss_diff = pd.DataFrame({'Segments':range(2,9),
                          'WCSS Difference': pd.Series(wcss).diff()})
wcss_diff['WCSS Difference'][0] = 0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\3704507040.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   wcss_diff['WCSS Difference'][0] = 0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\3704507040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wcss_diff['WCSS Difference'][0] = 0

# %%
plt.figure(figsize = (7, 4))
sns.barplot(wcss_diff, x = 'Segments', y = 'WCSS Difference')
plt.savefig("wcss_diff.png")
plt.show()

# %%
index_names = factor_loadings.index

# Plot data points
sns.scatterplot(data_pca, x = 'PC1', y = 'PC2', hue = 'cluster', palette = 'tab10')

# Plot arrows from centroid to provided coordinates with index names
for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text(factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# Set labels and legend
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Segment separation plot using principal components 1 and 2')
plt.grid(True)
plt.savefig("segment_separation.png")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\3651869897.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\3651869897.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# %%
data_desc = data_bw.copy()
data_desc['cluster'] = kmeans.labels_

# %%
data_desc.columns
# Out:
# Index(['review', 'Used it for', 'Owned for', 'Ridden for', 'rating',
#        'Visual Appeal', 'Reliability', 'Performance', 'Service Experience',
#        'Extra Features', 'Comfort', 'Maintenance cost', 'Value for Money',
#        'Model Name', 'sentiment', 'cluster'],
#       dtype='object')

# %%
def mosaicplot(df, color_list, figsize=(5,5), barwidth = 1, title = "Simple Mosaic Plot", xlabel = 'cat'):
    
    fig, ax = plt.subplots(figsize =figsize)
    
    # Convert to ratio of each row sum and do a cumsum along row
    p_cnt_ratio_df = df.div(df.sum(1), axis =0)
    ratio_cum_df = p_cnt_ratio_df.cumsum(axis=1)
    
    # Get column order.
    col_order = ratio_cum_df.columns.tolist()
        
    x = [str(n) for n in ratio_cum_df.index.tolist()]
    
    # Do the actual plots
    for col, colour in zip(col_order[::-1], color_list):
        plt.bar(x, ratio_cum_df[col], color=colour, edgecolor='white', width=barwidth, label=col)
        
    # Add in legend
    plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
    

    # Configure title and axis
    plt.title(title)
    plt.xlabel("Segments")
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.yticks([])
    plt.show()

# %%
sentiment_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['sentiment'])

# %%
color_list = ['#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#800080', '#FFA500']

# %%
sentiment_cluster
# Out:
# sentiment  negative  neutral  positive
# cluster
# 0                30       41       206
# 1               205        8       118
# 2                16        0        93
# 3                13        4       110

# %%
mosaicplot(sentiment_cluster, color_list[:3], figsize=(6,5), barwidth = 1)

# %%
used_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['Used it for'])

# %%
used_cluster
# Out:
# Used it for  Daily Commute  Everything  Leisure Rides  Occasional Commute  \
# cluster
# 0                      194          55              7                  19
# 1                      245          47              7                  27
# 2                       86          19              2                   1
# 3                       75          39              4                   9
#
# Used it for  Tours
# cluster
# 0                2
# 1                5
# 2                1
# 3                0

# %%
mosaicplot(used_cluster, color_list[:5], figsize=(6,5), barwidth = 1, title = 'Mosaic plot for cross-tabulation of clusters and used it for for the EV 2-Wheelers data set' )

# %%
owned_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['Owned for'])

# %%
owned_cluster
# Out:
# Owned for  3-6 months  6 months-1 yr  < 3 months  > 1 yr  Never owned  \
# cluster
# 0                  41             51          79      56           50
# 1                  40             56          67     117           50
# 2                  14             13          43      20           19
# 3                  16             14          31      10           56
#
# Owned for  Occasional Commute
# cluster
# 0                           0
# 1                           1
# 2                           0
# 3                           0

# %%
mosaicplot(owned_cluster, color_list[:6], figsize=(6,5), barwidth = 1, title = 'Mosaic plot for cross-tabulation of clusters and owned for for the EV 2-Wheelers data set' )

# %%
ridden_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['Ridden for'])

# %%
ridden_cluster
# Out:
# Ridden for  10000-15000 kms  5000-10000 kms  < 5000 kms  > 15000 kms  \
# cluster
# 0                        11              44         158           14
# 1                        15              61         185           18
# 2                         5              18          62            5
# 3                         1              15          54            1
#
# Ridden for  Never owned
# cluster
# 0                     0
# 1                     1
# 2                     0
# 3                     0

# %%
mosaicplot(ridden_cluster, color_list[:5], figsize=(6,5), barwidth = 1, title = 'Mosaic plot for cross-tabulation of clusters and ridden for for the EV 2-Wheelers data set' )

# %%
plt.figure(figsize = (5,4))
sns.boxplot(data_desc, x= 'cluster', y = 'rating', palette = 'tab10', width = 0.7)
plt.xlabel("Segments")
plt.ylabel("Rating")
plt.title("Parallel box and whisker plot of age by segment")
plt.savefig("rating.png")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13352\3346766999.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data_desc, x= 'cluster', y = 'rating', palette = 'tab10', width = 0.7)

# %%
plt.figure(figsize = (10, 12))
for i, col in enumerate(data_desc.columns[-8:-2]):
    plt.subplot(3, 2, i+1)
    sns.boxplot(data_desc, x = 'cluster', y =col)
    plt.xlabel("Segments", fontsize= 10)
    plt.ylabel(col, fontsize = 10)
    plt.xticks(fontsize = 8)
    plt.yticks(fontsize = 8)
plt.tight_layout()
plt.show()
